# %%
import xarray as xr
# %matplotlib inline
# Out:
# /home/alberta/anaconda2/envs/pangeo-cloud/lib/python3.6/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %%
ds=xr.open_dataset('/home/alberta/Téléchargements/SST_SSH_U_V_SLA_global_2004.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, time: 366)
# Coordinates:
#   * lon      (lon) float32 -179.875 -179.625 -179.375 ... 179.625 179.875
#   * lat      (lat) float32 -89.875 -89.625 -89.375 ... 89.375 89.625 89.875
#   * time     (time) datetime64[ns] 2004-01-01T12:00:00 ... 1981-01-01
# Data variables:
#     SST      (time, lat, lon) float32 ...
#     SSH      (time, lon, lat) float32 ...
#     U        (time, lon, lat) float32 ...
#     V        (time, lon, lat) float32 ...
#     SLA      (time, lon, lat) float32 ...
# Attributes:
#     CDI:                    Climate Data Interface version 1.5.3 (http://code...
#     Conventions:            CF-1.0
#     history:                Mon Jul 21 17:26:58 2014: cdo merge SST_SSH_U_V_g...
#     title:                  Analysed foundation sea surface temperature, global
#     DSD_entry_id:           REMSS-L4LRfnd-GLOB-tmi_amsre_OI
#     references:             none
#     source_data:            TMI-REMSS,AMSRE-REMSS
# ...

# %%
ds.SSH[0].plot()

# %%
ds_cut = ds.isel(lon=slice(5,65),lat=slice(30,48))

# %%
ds_cut.SSH[0].plot()

# %%
ds.SST[0].plot()

# %%
ds_cut.SST[0].plot()

# %%
SSH=ds.SSH
SST=ds.SST

# %%
SST_cut=SST.isel(lon=slice(5,65),lat=slice(30,48))
SSH_cut=SSH.isel(lon=slice(5,65),lat=slice(30,48))

# %%
SST_cut[0].plot()

# %%
SSH_cut[0].plot()

# %%
SSH
# Out:
# <xarray.DataArray 'SSH' (time: 366, lon: 1440, lat: 720)>
# [379468800 values with dtype=float32]
# Coordinates:
#   * lon      (lon) float32 -179.875 -179.625 -179.375 ... 179.625 179.875
#   * lat      (lat) float32 -89.875 -89.625 -89.375 ... 89.375 89.625 89.875
#   * time     (time) datetime64[ns] 2004-01-01T12:00:00 ... 1981-01-01
# Attributes:
#     long_name:        H
#     units:            cm
#     _CoordinateAxes:  time NbLongitudes NbLatitudes

# %%
SST
# Out:
# <xarray.DataArray 'SST' (time: 366, lat: 720, lon: 1440)>
# [379468800 values with dtype=float32]
# Coordinates:
#   * lon      (lon) float32 -179.875 -179.625 -179.375 ... 179.625 179.875
#   * lat      (lat) float32 -89.875 -89.625 -89.375 ... 89.375 89.625 89.875
#   * time     (time) datetime64[ns] 2004-01-01T12:00:00 ... 1981-01-01
# Attributes:
#     standard_name:  sea_surface_temperature
#     long_name:      analysed sea surface temperature
#     units:          kelvin
#     type:           foundation
#     valid_min:      -300
#     valid_max:      4500
#     source:         REMSS

# %%
del SSH.attrs['_CoordinateAxes']

# %%
SSH
# Out:
# <xarray.DataArray 'SSH' (time: 366, lon: 1440, lat: 720)>
# [379468800 values with dtype=float32]
# Coordinates:
#   * lon      (lon) float32 -179.875 -179.625 -179.375 ... 179.625 179.875
#   * lat      (lat) float32 -89.875 -89.625 -89.375 ... 89.375 89.625 89.875
#   * time     (time) datetime64[ns] 2004-01-01T12:00:00 ... 1981-01-01
# Attributes:
#     long_name:  H
#     units:      cm

# %%
SSH_recut=SSH.isel(lon=slice(5,65),lat=slice(30,48))

# %%
SSH_recut[0].plot()

# %%
SSH_transpose=SSH.transpose('time','lat','lon')

# %%
SSH_transpose
# Out:
# <xarray.DataArray 'SSH' (time: 366, lat: 720, lon: 1440)>
# [379468800 values with dtype=float32]
# Coordinates:
#   * lon      (lon) float32 -179.875 -179.625 -179.375 ... 179.625 179.875
#   * lat      (lat) float32 -89.875 -89.625 -89.375 ... 89.375 89.625 89.875
#   * time     (time) datetime64[ns] 2004-01-01T12:00:00 ... 1981-01-01
# Attributes:
#     long_name:  H
#     units:      cm

# %%
SSH_transpose[0].plot()

# %%
SSH_trans_cut=SSH_transpose.isel(lon=slice(5,65),lat=slice(30,48))

# %%
SSH_trans_cut[0].plot()

# %%
SSH_trans_cut_lon=SSH_transpose.isel(lon=slice(5,65))

# %%
SSH_trans_cut_lon[0].plot()

# %%
SSH_trans_cut_lat=SSH_transpose.isel(lat=slice(30,48))

# %%
SSH_trans_cut_lat[0].plot()

# %%
ds.lat.isel(lat=slice(30,48)).values
# Out:
# array([-82.375, -82.125, -81.875, -81.625, -81.375, -81.125, -80.875,
#        -80.625, -80.375, -80.125, -79.875, -79.625, -79.375, -79.125,
#        -78.875, -78.625, -78.375, -78.125], dtype=float32)
